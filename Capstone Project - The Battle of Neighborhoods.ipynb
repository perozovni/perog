# %% [markdown]
# # Capstone Project - The Battle of the Neighborhoods - complete
# ### Analyse for  secure location in Baltimore

# %% [markdown]
# ## Problem desription
#
# Goal of project is to detect secure location where new family moving from Europe with 2 kids could get apartment in **Baltimore, US**.
#
# Intention is to detect which district have least violence taken from official **Baltimore Police Department** web pages.
#
# Idea would be to list down **top 5 districts** for better locations.
#
#
# ## Data which will be used for solving problem
#
# Since problem is to find best place for living in Baltimore with respect of how big crime step  can be expected in particular district, most reliable data will be police report
#
# Next data sources will help to solve problem:
#
# - **Data set 1**: Data from Baltimore police department:  Data sheet of all Part I crime incidents within Baltimore City: https://www.baltimorepolice.org/crime-stats/open-data
#
# - **Data set 2**: List of Baltimore neighborhoods from Wikipedia: Wikipedia list of Baltimore neighborhoods: https://en.wikipedia.org/wiki/List_of_Baltimore_neighborhoods

# %% [markdown]
# #### Libraries import

# %%
import numpy as np
import pandas as pd
# !pip install opencage

# %matplotlib inline 
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.style.use('ggplot') # optional: for ggplot-like style
print ('Matplotlib version: ', mpl.__version__) # >= 2.0.0

import matplotlib.cm as cm
import matplotlib.colors as colors
import requests
from pandas.io.json import json_normalize
from sklearn.cluster import KMeans

print('Libraries are imported')
# Out:
# Requirement already satisfied: opencage in /opt/conda/envs/Python36/lib/python3.6/site-packages (1.2.1)
# Requirement already satisfied: backoff>=1.10.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from opencage) (1.10.0)
# Requirement already satisfied: pyopenssl>=0.15.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from opencage) (19.0.0)
# Requirement already satisfied: Requests>=2.2.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from opencage) (2.21.0)
# Requirement already satisfied: six>=1.4.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from opencage) (1.12.0)
# Requirement already satisfied: cryptography>=2.3 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pyopenssl>=0.15.1->opencage) (2.5)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from Requests>=2.2.0->opencage) (2020.4.5.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from Requests>=2.2.0->opencage) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from Requests>=2.2.0->opencage) (1.24.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from Requests>=2.2.0->opencage) (3.0.4)
# Requirement already satisfied: asn1crypto>=0.21.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from cryptography>=2.3->pyopenssl>=0.15.1->opencage) (0.24.0)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from cryptography>=2.3->pyopenssl>=0.15.1->opencage) (1.11.5)
# Requirement already satisfied: pycparser in /opt/conda/envs/Python36/lib/python3.6/site-packages (from cffi!=1.11.3,>=1.8->cryptography>=2.3->pyopenssl>=0.15.1->opencage) (2.19)
# Matplotlib version:  3.0.2
# Libraries are imported

# %% [markdown]
# #### Downloading and reading police department data

# %%
baltimore_crime_df = pd.read_csv('https://raw.githubusercontent.com/perozovni/perog/master/Baltimore_crimes.csv', index_col=0)
baltimore_crime_df.drop(['CrimeCode','Location','Inside/Outside','Neighborhood','Longitude','Latitude','Location 1','Weapon','Total Incidents'], axis = 1, inplace = True)
baltimore_crime_df.dropna(how="all", inplace=True)
#crime_df.columns
baltimore_crime_df.head()
# Out:
#            CrimeTime          Description   Post      District     Premise
# CrimeDate
# 08/31/2017  16:04:00     ROBBERY - STREET  843.0  SOUTHWESTERN         NaN
# 08/31/2017  14:30:00              LARCENY  511.0      NORTHERN  HOSP/NURS.
# 01/19/2017  19:35:00     ROBBERY - STREET  211.0  SOUTHEASTERN      STREET
# 08/30/2017  22:30:00    LARCENY FROM AUTO  612.0  NORTHWESTERN       ALLEY
# 01/02/2017  08:50:00  ROBBERY - RESIDENCE  425.0  NORTHEASTERN  ROW/TOWNHO

# %% [markdown]
# #### List down most violence districts

# %%
baltimore_crime_df['District'].value_counts()
# Out:
# NORTHEASTERN    12
# SOUTHEASTERN    12
# EASTERN         10
# NORTHWESTERN     9
# SOUTHERN         9
# CENTRAL          8
# SOUTHWESTERN     7
# NORTHERN         6
# WESTERN          6
# Name: District, dtype: int64

# %% [markdown]
# #### List down crime desription

# %%
baltimore_crime_df['Description'].value_counts()
# Out:
# COMMON ASSAULT         18
# AUTO THEFT             17
# LARCENY                12
# AGG. ASSAULT           12
# LARCENY FROM AUTO      11
# ROBBERY - STREET        5
# BURGLARY                5
# ROBBERY - RESIDENCE     2
# ASSAULT BY THREAT       1
# Name: Description, dtype: int64

# %% [markdown]
# ## Methodology

# %% [markdown]
# ### Table for correlation of crime premise with city district

# %%
baltimore_crime_cat = pd.pivot_table(baltimore_crime_df,values=['CrimeTime'],index=['District'],columns=['Premise'],
                               aggfunc=len,
                               fill_value=0,
                               margins=True)
baltimore_crime_cat
# Out:
#              CrimeTime                                                       \
# Premise          ALLEY APT/CONDO GARAGE ON GAS STATIO HOSP/NURS. OFFICE BUI
# District
# CENTRAL              0         0         0          0          0          0
# EASTERN              0         1         0          0          0          0
# NORTHEASTERN         0         0         0          1          0          0
# NORTHERN             0         0         1          0          1          0
# NORTHWESTERN         1         1         0          0          0          0
# SOUTHEASTERN         0         0         0          0          0          0
# SOUTHERN             0         0         0          0          0          1
# SOUTHWESTERN         0         0         0          0          0          0
# WESTERN              0         0         0          0          0          0
# All                  1         2         1          1          1          1
#
#
# Premise      OTHER - OU PARK PARKING LO ROW/TOWNHO STREET YARD All
# District
# CENTRAL               0    0          0          1      5    0   6
# EASTERN               0    0          0          2      3    0   6
# NORTHEASTERN          0    0          1          4      5    0  11
# NORTHERN              1    1          0          0      0    0   4
# NORTHWESTERN          1    0          0          1      4    0   8
# SOUTHEASTERN          0    0          2          0      8    0  10
# SOUTHERN              0    0          1          0      6    0   8
# SOUTHWESTERN          0    0          0          1      2    1   4
# WESTERN               0    0          0          0      5    0   5
# All                   2    1          4          9     38    1  62

# %% [markdown]
# ### Table for correlation of post office, city district with desctipion of violence

# %%
baltimore_crime_cat = pd.pivot_table(baltimore_crime_df,values=['CrimeTime'],index=['Post','District'],columns=['Description'],
                               aggfunc=len,
                               fill_value=0,
                               margins=True)
baltimore_crime_cat
# Out:
#                       CrimeTime                                        \
# Description        AGG. ASSAULT ASSAULT BY THREAT AUTO THEFT BURGLARY
# Post  District
# 111.0 CENTRAL                 0                 0          0        0
# 121.0 CENTRAL                 1                 0          0        0
# 123.0 CENTRAL                 1                 0          0        0
# 132.0 CENTRAL                 0                 0          0        1
# 142.0 CENTRAL                 0                 0          0        0
# 211.0 SOUTHEASTERN            0                 0          1        0
# 223.0 SOUTHEASTERN            1                 0          0        0
# 224.0 SOUTHEASTERN            0                 0          0        0
# 232.0 SOUTHEASTERN            0                 0          0        0
# 233.0 SOUTHEASTERN            0                 0          1        0
# 243.0 SOUTHEASTERN            1                 0          2        0
# 312.0 EASTERN                 0                 0          0        0
# 321.0 EASTERN                 0                 0          0        0
# 322.0 EASTERN                 0                 0          0        0
# 323.0 EASTERN                 1                 0          0        0
# 342.0 EASTERN                 0                 0          1        0
# 343.0 EASTERN                 0                 0          0        0
# 411.0 NORTHEASTERN            1                 0          0        0
# 423.0 NORTHEASTERN            0                 0          1        1
# 424.0 NORTHEASTERN            0                 0          0        0
# 425.0 NORTHEASTERN            0                 0          0        0
# 426.0 NORTHEASTERN            0                 0          0        0
# 441.0 NORTHEASTERN            0                 0          0        0
# 442.0 NORTHEASTERN            0                 0          0        1
# 443.0 NORTHEASTERN            0                 0          0        1
# 511.0 NORTHERN                0                 0          1        0
# 531.0 NORTHERN                0                 0          1        1
# 611.0 NORTHWESTERN            0                 0          1        0
# 612.0 NORTHWESTERN            0                 0          0        0
# 614.0 NORTHWESTERN            0                 0          0        0
# 623.0 NORTHWESTERN            0                 0          1        0
# 631.0 NORTHWESTERN            0                 1          1        0
# 632.0 NORTHWESTERN            0                 0          0        0
# 642.0 NORTHWESTERN            1                 0          0        0
# 731.0 WESTERN                 0                 0          1        0
# 732.0 WESTERN                 0                 0          0        0
# 741.0 WESTERN                 0                 0          1        0
# 742.0 WESTERN                 0                 0          1        0
# 743.0 WESTERN                 0                 0          0        0
# 814.0 SOUTHWESTERN            1                 0          0        0
# 822.0 SOUTHWESTERN            0                 0          1        0
# 823.0 SOUTHWESTERN            0                 0          1        0
# 831.0 SOUTHWESTERN            1                 0          0        0
# 833.0 SOUTHWESTERN            0                 0          0        0
# 843.0 SOUTHWESTERN            0                 0          0        0
# 844.0 SOUTHWESTERN            0                 0          0        0
# 911.0 SOUTHERN                1                 0          1        0
# 912.0 SOUTHERN                1                 0          0        0
# 913.0 SOUTHERN                0                 0          0        0
# 922.0 SOUTHERN                0                 0          0        0
# 932.0 SOUTHERN                1                 0          0        0
# 942.0 SOUTHERN                0                 0          0        0
# 945.0 SOUTHERN                0                 0          0        0
# All                          12                 1         17        5
#
#                                                              \
# Description        COMMON ASSAULT LARCENY LARCENY FROM AUTO
# Post  District
# 111.0 CENTRAL                   1       0                 0
# 121.0 CENTRAL                   2       0                 0
# 123.0 CENTRAL                   0       1                 0
# 132.0 CENTRAL                   0       0                 0
# 142.0 CENTRAL                   0       1                 0
# 211.0 SOUTHEASTERN              1       0                 1
# 223.0 SOUTHEASTERN              0       0                 0
# 224.0 SOUTHEASTERN              0       0                 1
# 232.0 SOUTHEASTERN              0       0                 1
# 233.0 SOUTHEASTERN              0       0                 0
# 243.0 SOUTHEASTERN              1       0                 0
# 312.0 EASTERN                   2       0                 0
# 321.0 EASTERN                   0       0                 1
# 322.0 EASTERN                   0       0                 1
# 323.0 EASTERN                   0       0                 0
# 342.0 EASTERN                   1       1                 0
# 343.0 EASTERN                   2       0                 0
# 411.0 NORTHEASTERN              0       0                 0
# 423.0 NORTHEASTERN              0       0                 0
# 424.0 NORTHEASTERN              1       0                 0
# 425.0 NORTHEASTERN              1       0                 0
# 426.0 NORTHEASTERN              0       1                 0
# 441.0 NORTHEASTERN              0       0                 1
# 442.0 NORTHEASTERN              0       0                 0
# 443.0 NORTHEASTERN              0       1                 0
# 511.0 NORTHERN                  0       1                 0
# 531.0 NORTHERN                  0       0                 2
# 611.0 NORTHWESTERN              0       0                 0
# 612.0 NORTHWESTERN              0       0                 1
# 614.0 NORTHWESTERN              1       0                 0
# 623.0 NORTHWESTERN              0       0                 0
# 631.0 NORTHWESTERN              0       0                 0
# 632.0 NORTHWESTERN              0       1                 0
# 642.0 NORTHWESTERN              0       0                 0
# 731.0 WESTERN                   0       0                 0
# 732.0 WESTERN                   0       1                 0
# 741.0 WESTERN                   0       1                 0
# 742.0 WESTERN                   0       0                 0
# 743.0 WESTERN                   0       0                 1
# 814.0 SOUTHWESTERN              0       0                 0
# 822.0 SOUTHWESTERN              0       0                 0
# 823.0 SOUTHWESTERN              0       0                 0
# 831.0 SOUTHWESTERN              0       0                 0
# 833.0 SOUTHWESTERN              1       0                 0
# 843.0 SOUTHWESTERN              0       0                 0
# 844.0 SOUTHWESTERN              0       1                 0
# 911.0 SOUTHERN                  0       0                 0
# 912.0 SOUTHERN                  0       0                 0
# 913.0 SOUTHERN                  0       0                 1
# 922.0 SOUTHERN                  0       1                 0
# 932.0 SOUTHERN                  0       1                 0
# 942.0 SOUTHERN                  1       0                 0
# 945.0 SOUTHERN                  0       0                 0
# All                            15      12                11
#
#
# Description        ROBBERY - RESIDENCE ROBBERY - STREET All
# Post  District
# 111.0 CENTRAL                        0                0   1
# 121.0 CENTRAL                        0                0   3
# 123.0 CENTRAL                        0                0   2
# 132.0 CENTRAL                        0                0   1
# 142.0 CENTRAL                        0                0   1
# 211.0 SOUTHEASTERN                   0                1   4
# 223.0 SOUTHEASTERN                   0                0   1
# 224.0 SOUTHEASTERN                   0                0   1
# 232.0 SOUTHEASTERN                   0                0   1
# 233.0 SOUTHEASTERN                   0                0   1
# 243.0 SOUTHEASTERN                   0                0   4
# 312.0 EASTERN                        0                0   2
# 321.0 EASTERN                        0                0   1
# 322.0 EASTERN                        0                0   1
# 323.0 EASTERN                        0                0   1
# 342.0 EASTERN                        0                0   3
# 343.0 EASTERN                        0                0   2
# 411.0 NORTHEASTERN                   0                0   1
# 423.0 NORTHEASTERN                   0                0   2
# 424.0 NORTHEASTERN                   0                0   1
# 425.0 NORTHEASTERN                   1                0   2
# 426.0 NORTHEASTERN                   0                1   2
# 441.0 NORTHEASTERN                   0                0   1
# 442.0 NORTHEASTERN                   0                0   1
# 443.0 NORTHEASTERN                   0                0   2
# 511.0 NORTHERN                       0                0   2
# 531.0 NORTHERN                       0                0   4
# 611.0 NORTHWESTERN                   0                0   1
# 612.0 NORTHWESTERN                   0                0   1
# 614.0 NORTHWESTERN                   0                0   1
# 623.0 NORTHWESTERN                   0                0   1
# 631.0 NORTHWESTERN                   0                0   2
# 632.0 NORTHWESTERN                   0                0   1
# 642.0 NORTHWESTERN                   1                0   2
# 731.0 WESTERN                        0                0   1
# 732.0 WESTERN                        0                0   1
# 741.0 WESTERN                        0                0   2
# 742.0 WESTERN                        0                0   1
# 743.0 WESTERN                        0                0   1
# 814.0 SOUTHWESTERN                   0                0   1
# 822.0 SOUTHWESTERN                   0                0   1
# 823.0 SOUTHWESTERN                   0                0   1
# 831.0 SOUTHWESTERN                   0                0   1
# 833.0 SOUTHWESTERN                   0                0   1
# 843.0 SOUTHWESTERN                   0                1   1
# 844.0 SOUTHWESTERN                   0                0   1
# 911.0 SOUTHERN                       0                0   2
# 912.0 SOUTHERN                       0                0   1
# 913.0 SOUTHERN                       0                0   1
# 922.0 SOUTHERN                       0                0   1
# 932.0 SOUTHERN                       0                0   2
# 942.0 SOUTHERN                       0                0   1
# 945.0 SOUTHERN                       0                1   1
# All                                  2                4  79

# %% [markdown]
# ### Basic statistical details

# %%
baltimore_crime_cat.describe()
# Out:
#                CrimeTime                                          \
# Description AGG. ASSAULT ASSAULT BY THREAT AUTO THEFT   BURGLARY
# count          54.000000         54.000000  54.000000  54.000000
# mean            0.444444          0.037037   0.629630   0.185185
# std             1.655940          0.190626   2.325383   0.728764
# min             0.000000          0.000000   0.000000   0.000000
# 25%             0.000000          0.000000   0.000000   0.000000
# 50%             0.000000          0.000000   0.000000   0.000000
# 75%             0.000000          0.000000   1.000000   0.000000
# max            12.000000          1.000000  17.000000   5.000000
#
#                                                                              \
# Description COMMON ASSAULT    LARCENY LARCENY FROM AUTO ROBBERY - RESIDENCE
# count            54.000000  54.000000         54.000000           54.000000
# mean              0.555556   0.444444          0.407407            0.074074
# std               2.080155   1.655940          1.535965            0.328050
# min               0.000000   0.000000          0.000000            0.000000
# 25%               0.000000   0.000000          0.000000            0.000000
# 50%               0.000000   0.000000          0.000000            0.000000
# 75%               0.000000   0.000000          0.000000            0.000000
# max              15.000000  12.000000         11.000000            2.000000
#
#
# Description ROBBERY - STREET        All
# count              54.000000  54.000000
# mean                0.148148   2.925926
# std                 0.595816  10.579175
# min                 0.000000   1.000000
# 25%                 0.000000   1.000000
# 50%                 0.000000   1.000000
# 75%                 0.000000   2.000000
# max                 4.000000  79.000000

# %% [markdown]
# ### Discussion and Conlusion
# As initially stated problem was detect most safer part of Baltimore City in order to have safe family living.
# Data analysis showed that SOUTHEASTERN district is most violent district while WESTERN district is least violent district with less crimes committed.
#
# #### Taking in account crime data from Baltimore police department conclusion is that most safest district in Baltimore would be Western district.
